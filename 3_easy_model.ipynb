# %% [markdown]
# 1. 불러오기
# - 2_token.ipynb에서 저장한 파일을 불러온다.

# %%
#라이브러리 import
import pickle

# %%
with open('token.pickle', 'rb') as f:
    token = pickle.load(f)
len(token)
# Out:
# 1

# %%
token[0]
# Out:
# [['어리',
#   'ㄴ',
#   '햇살',
#   '아래',
#   '서',
#   '뛰어놀',
#   '곤',
#   '하',
#   '었',
#   '었',
#   '더',
#   'ㄴ',
#   '가쁘',
#   'ㄴ',
#   '숨결',
#   '굽이지',
#   'ㄴ',
#   '골목',
#   '지나',
#   '기',
#   '를',
#   '을',
#   '따르',
#   '아',
#   '가보',
#   '면',
#   '같',
#   '은',
#   '기억',
#   '어른',
#   '이',
#   '란',
#   '시간',
#   '은',
#   '아직',
#   '어색',
#   '하',
#   '게',
#   '도',
#   '나',
#   '를',
#   '채우',
#   '어',
#   '많',
#   '은',
#   '것',
#   '이',
#   '변하',
#   '었',
#   '다',
#   '하',
#   '어',
#   '여기',
#   'ㄴ',
#   '그대로',
#   '인걸',
#   'you',
#   '’',
#   'll',
#   'feel',
#   'the',
#   'same',
#   '땀',
#   '에',
#   '젖',
#   '어',
#   '놀',
#   '았',
#   '던',
#   '우리',
#   '는',
#   '너와',
#   '낳',
#   'ㄴ',
#   '이젠',
#   '돌아가',
#   'ㄹ',
#   '순',
#   '없',
#   '지만',
#   '낡',
#   '아',
#   '진',
#   '서랍',
#   '속',
#   '에서',
#   '작',
#   '았',
#   '더',
#   'ㄴ',
#   '서',
#   '롤',
#   '기억',
#   '하',
#   '어',
#   'when',
#   'i',
#   '’',
#   'm',
#   'far',
#   'from',
#   'home',
#   'always',
#   '떠오',
# ...
